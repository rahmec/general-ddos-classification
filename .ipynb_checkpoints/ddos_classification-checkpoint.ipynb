# %%
import importlib.util
import sys

# Path hydra
file_path = './hydra/hydra_multivariate.py'
file_path2 = './hydra/hydra.py'

# Caricamento
spec = importlib.util.spec_from_file_location("hydra", file_path)
spec2 = importlib.util.spec_from_file_location("hydra2", file_path2)
hydra = importlib.util.module_from_spec(spec)
hydra2 = importlib.util.module_from_spec(spec2)
sys.modules["hydra"] = hydra
spec.loader.exec_module(hydra)
sys.modules["hydra2"] = hydra2
spec2.loader.exec_module(hydra2)

HydraMultivariate = hydra.HydraMultivariate
SparseScaler = hydra2.SparseScaler 

print("HydraMultivariate e SparseScaler caricati correttamente!")

# Metodo per la creazione delle sequenze per hydra
def create_sequences(data, seq_length, window):
    sequences = []
    for i in range(0, len(data) - seq_length + 1, window):
        sequence = data[i:i+seq_length]
        sequences.append(sequence)
    return np.array(sequences)
# Out:
# HydraMultivariate e SparseScaler caricati correttamente!

# %%
import pandas as pd
import numpy as np
import torch
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import MinMaxScaler
from sklearn.neighbors import KNeighborsClassifier

def tune_n_for_knn(seq_lengths, dfs, hydra_df=False, win_slide=10):
    knn_best_params = []
    for i in range(len(dfs)):
        df = dfs[i]

        if not hydra_df:
            X = df.drop(columns=['label','avg_flow_number'])
            Y = df['label']
        else:
            features = [
            'byte_rate', 'packet_rate', 'avg_deltatime',
            'source_entropy', 'destination_entropy', 's-port_entropy',
            'd-port_entropy', 'synack_ratio', 'modbus_rate', 'tcp_rate',
            'ping_rate', 'other_rate'
            ]
            hydra_seq_length = 10
            hydra_window_slide = int(win_slide)
            feature_sequences = [create_sequences(df[feature].values, hydra_seq_length, hydra_window_slide) for feature in features]
            sequences_tensor = torch.tensor(np.stack(feature_sequences, axis=1), dtype=torch.float32)
            labels = df['label'].values
            labels_seq = create_sequences(labels, hydra_seq_length, hydra_window_slide)
            labels_tensor = torch.tensor(labels_seq[:, -1], dtype=torch.long)
            hydra_multivariate = HydraMultivariate(input_length=seq_length, num_channels=4)
            X = hydra_multivariate.batch(sequences_tensor)
            scaler = SparseScaler()
            X = scaler.fit_transform(X)
            Y = labels_tensor
            
        scaler = MinMaxScaler()
        X = scaler.fit_transform(X)
        print(f"Number of rows: {X.shape[0]}")
        classifier = KNeighborsClassifier()
        param_grid = {
            'n_neighbors': range(1,20),
            'weights': ['uniform', 'distance']
        }
        grid_search = GridSearchCV(classifier, param_grid, cv=5)
        grid_search.fit(X, Y)
        params = grid_search.best_params_
        knn_best_params.append(params)
        print(f"DF {i} best params: {params}")
    return knn_best_params

print("##############################################################")
print("               KNN   tuning  (5 cross validation)             ")
print("##############################################################")

seq_lengths_packets = [10, 50, 100, 250, 500]
seq_lengths_time = [1, 2, 5, 10, 30]

dfs_packets = []
dfs_time = []
best_params = []

for seq_length in seq_lengths_packets:
    df = pd.read_csv(f'csv/aggregated_{seq_length}packets_df.csv')
    dfs_packets.append(df)

for seq_length in seq_lengths_time:
    df = pd.read_csv(f'csv/aggregated_time_{seq_length}s_df.csv')
    dfs_time.append(df)

print("Sequenze per pacchetti - NO HYDRA")
best_params.append(tune_n_for_knn(seq_lengths_packets, dfs_packets))
print(best_params[0])
print("Sequenze per tempo - NO HYDRA")
best_params.append(tune_n_for_knn(seq_lengths_packets, dfs_time))
print(best_params[1])
print("Sequenze per pacchetti - HYDRA")
best_params.append(tune_n_for_knn(seq_lengths_packets, dfs_packets, hydra_df=True, win_slide=10))
print(best_params[2])
print("Sequenze per tempo - HYDRA")
best_params.append(tune_n_for_knn(seq_lengths_packets, dfs_time, hydra_df=True, win_slide=3))
print(best_params[3])
# Out:
# ##############################################################
#                KNN n tuning  (5 cross validation)
# ##############################################################
# Sequenze per pacchetti - NO HYDRA
# Number of rows: 108079
# DF 0 best params: {'n_neighbors': 2, 'weights': 'uniform'}
# Number of rows: 21614
# DF 1 best params: {'n_neighbors': 2, 'weights': 'uniform'}
# Number of rows: 10806
# DF 2 best params: {'n_neighbors': 2, 'weights': 'uniform'}
# Number of rows: 4322
# DF 3 best params: {'n_neighbors': 1, 'weights': 'uniform'}
# Number of rows: 2159
# DF 4 best params: {'n_neighbors': 2, 'weights': 'uniform'}
# [{'n_neighbors': 2, 'weights': 'uniform'}, {'n_neighbors': 2, 'weights': 'uniform'}, {'n_neighbors': 2, 'weights': 'uniform'}, {'n_neighbors': 1, 'weights': 'uniform'}, {'n_neighbors': 2, 'weights': 'uniform'}]
# Sequenze per tempo - NO HYDRA
# Number of rows: 6994
# DF 0 best params: {'n_neighbors': 12, 'weights': 'uniform'}
# Number of rows: 3596
# DF 1 best params: {'n_neighbors': 2, 'weights': 'uniform'}
# Number of rows: 1436
# DF 2 best params: {'n_neighbors': 3, 'weights': 'uniform'}
# Number of rows: 716
# DF 3 best params: {'n_neighbors': 1, 'weights': 'uniform'}
# Number of rows: 236
# DF 4 best params: {'n_neighbors': 1, 'weights': 'uniform'}
# [{'n_neighbors': 12, 'weights': 'uniform'}, {'n_neighbors': 2, 'weights': 'uniform'}, {'n_neighbors': 3, 'weights': 'uniform'}, {'n_neighbors': 1, 'weights': 'uniform'}, {'n_neighbors': 1, 'weights': 'uniform'}]
# Sequenze per pacchetti - HYDRA
# Number of rows: 10807
# DF 0 best params: {'n_neighbors': 14, 'weights': 'distance'}
# Number of rows: 2161
# DF 1 best params: {'n_neighbors': 5, 'weights': 'uniform'}
# Number of rows: 1080
# DF 2 best params: {'n_neighbors': 1, 'weights': 'uniform'}
# Number of rows: 432
# DF 3 best params: {'n_neighbors': 2, 'weights': 'uniform'}
# Number of rows: 215
# DF 4 best params: {'n_neighbors': 2, 'weights': 'uniform'}
# [{'n_neighbors': 14, 'weights': 'distance'}, {'n_neighbors': 5, 'weights': 'uniform'}, {'n_neighbors': 1, 'weights': 'uniform'}, {'n_neighbors': 2, 'weights': 'uniform'}, {'n_neighbors': 2, 'weights': 'uniform'}]
# Sequenze per tempo - HYDRA
# Number of rows: 2329
# DF 0 best params: {'n_neighbors': 1, 'weights': 'uniform'}
# Number of rows: 1196
# DF 1 best params: {'n_neighbors': 18, 'weights': 'distance'}
# Number of rows: 476
# DF 2 best params: {'n_neighbors': 7, 'weights': 'distance'}
# Number of rows: 236
# DF 3 best params: {'n_neighbors': 14, 'weights': 'distance'}
# Number of rows: 76
# DF 4 best params: {'n_neighbors': 4, 'weights': 'distance'}
# [{'n_neighbors': 1, 'weights': 'uniform'}, {'n_neighbors': 18, 'weights': 'distance'}, {'n_neighbors': 7, 'weights': 'distance'}, {'n_neighbors': 14, 'weights': 'distance'}, {'n_neighbors': 4, 'weights': 'distance'}]

# %%
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.svm import LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, f1_score
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
import time

kfold_splits=5

skf = StratifiedKFold(n_splits=kfold_splits, shuffle=True, random_state=42)

DTClassifier = DecisionTreeClassifier(random_state=777)
RFClassifier = RandomForestClassifier(random_state=777)
KNNClassifier = KNeighborsClassifier()
SVMClassifier = LinearSVC(random_state=777)
classifiers = [DTClassifier, RFClassifier, KNNClassifier, SVMClassifier]

seq_lengths1 = [10, 50, 100, 250, 500]
dfs1 = []

for seq_length in seq_lengths1:
    df = pd.read_csv(f'csv/aggregated_{seq_length}packets_df.csv')
    dfs1.append(df)

accuracies_per_classifier1 = [[0 for _ in dfs1] for _ in classifiers]
f1scores_per_classifier1 = [[0 for _ in dfs1] for _ in classifiers]
training_times_per_classifier1 = [[0 for _ in dfs1] for _ in classifiers]
prediction_times_per_classifier1 = [[0 for _ in dfs1] for _ in classifiers]

print("##############################################################")
print("              SEQUENZE PER PACCHETTI (NO HYDRA)               ")
print("##############################################################")

for i in range(len(dfs1)):
    print("##############################################################")
    print(f"DF: {i}")

    aggregated_df = dfs1[i]
    labels = aggregated_df['label'].values
    X = aggregated_df.drop(columns=['label',])
    Y = aggregated_df['label']
    X = X.drop(columns=['avg_flow_number',])
    
    for j in range(len(classifiers)):

        classifier = classifiers[j]
        print(f"Classifier: {classifier}")
        
        accuracies = []
        f1scores = []
        training_times = []
        prediction_times = []

        fold_iteration = 0
        for train_index, test_index in skf.split(X, Y):
            X_train, X_test = X.iloc[train_index], X.iloc[test_index]
            Y_train, Y_test = Y.iloc[train_index], Y.iloc[test_index]

            if(j>=2):
                scaler = MinMaxScaler()
                X_train = scaler.fit_transform(X_train)
                X_test = scaler.transform(X_test)
                X_train = pd.DataFrame(X_train, columns=X.columns)
                X_test = pd.DataFrame(X_test, columns=X.columns)
                if(j==2):
                    params = best_params[0][fold_iteration]
                    n = params['n_neighbors']
                    weight = params['weights']
                    classifier.set_params(n_neighbors=n, weights=weight)

            start = time.time()
            classifier.fit(X_train, Y_train)
            end = time.time()
            training_times.append(end-start)
            
            start = time.time()
            Y_pred = classifier.predict(X_test)
            end = time.time()
            prediction_times.append(end-start)
            
            acc = accuracy_score(Y_test, Y_pred)
            accuracies.append(acc)
            f1score = f1_score(Y_test, Y_pred, average='macro')
            f1scores.append(f1score)
        
            print(f"Fold {fold_iteration} Accuracy: {acc}")
            fold_iteration += 1
            
        accuracies_per_classifier1[j][i] = np.mean(accuracies)
        f1scores_per_classifier1[j][i] = np.mean(f1scores)
        training_times_per_classifier1[j][i] = np.mean(training_times)
        prediction_times_per_classifier1[j][i] = np.mean(prediction_times)
# Out:
# ##############################################################
#               SEQUENZE PER PACCHETTI (NO HYDRA)
# ##############################################################
# ##############################################################
# DF: 0
# Classifier: DecisionTreeClassifier(random_state=777)
# Fold 0 Accuracy: 0.9646095484826055
# Fold 1 Accuracy: 0.9664600296076981
# Fold 2 Accuracy: 0.964100666173205
# Fold 3 Accuracy: 0.9656735751295337
# Fold 4 Accuracy: 0.9672912329400879
# Classifier: RandomForestClassifier(random_state=777)
# Fold 0 Accuracy: 0.967940414507772
# Fold 1 Accuracy: 0.9673852701702442
# Fold 2 Accuracy: 0.9653497409326425
# Fold 3 Accuracy: 0.9671539600296077
# Fold 4 Accuracy: 0.9678464029609067
# Classifier: KNeighborsClassifier(n_neighbors=50)
# Fold 0 Accuracy: 0.967200222057735
# Fold 1 Accuracy: 0.9685880829015544
# Fold 2 Accuracy: 0.9659511472982976
# Fold 3 Accuracy: 0.966321243523316
# Fold 4 Accuracy: 0.9687254221605367
# Classifier: LinearSVC(random_state=777)
# Fold 0 Accuracy: 0.9637768319763138
# Fold 1 Accuracy: 0.9659974093264249
# Fold 2 Accuracy: 0.9628515914137675
# Fold 3 Accuracy: 0.9640081421169504
# Fold 4 Accuracy: 0.9650242886884108
# ##############################################################
# DF: 1
# Classifier: DecisionTreeClassifier(random_state=777)
# Fold 0 Accuracy: 0.9770992366412213
# Fold 1 Accuracy: 0.9821882951653944
# Fold 2 Accuracy: 0.9808003701133472
# Fold 3 Accuracy: 0.9770992366412213
# Fold 4 Accuracy: 0.979639055992596
# Classifier: RandomForestClassifier(random_state=777)
# Fold 0 Accuracy: 0.9794124450613
# Fold 1 Accuracy: 0.9814943326393708
# Fold 2 Accuracy: 0.9824196160074022
# Fold 3 Accuracy: 0.9821882951653944
# Fold 4 Accuracy: 0.9831096714484036
# Classifier: KNeighborsClassifier(n_neighbors=2)
# Fold 0 Accuracy: 0.9782558408512607
# Fold 1 Accuracy: 0.982882257691418
# Fold 2 Accuracy: 0.9831135785334258
# Fold 3 Accuracy: 0.9780245200092529
# Fold 4 Accuracy: 0.98149005090236
# Classifier: LinearSVC(random_state=777)
# Fold 0 Accuracy: 0.9736294240111034
# Fold 1 Accuracy: 0.9775618783252371
# Fold 2 Accuracy: 0.9777931991672449
# Fold 3 Accuracy: 0.972704140643072
# Fold 4 Accuracy: 0.9754743174456271
# ##############################################################
# DF: 2
# Classifier: DecisionTreeClassifier(random_state=777)
# Fold 0 Accuracy: 0.9851988899167438
# Fold 1 Accuracy: 0.983803794539565
# Fold 2 Accuracy: 0.978713558537714
# Fold 3 Accuracy: 0.98149005090236
# Fold 4 Accuracy: 0.978250809810273
# Classifier: RandomForestClassifier(random_state=777)
# Fold 0 Accuracy: 0.9838112858464385
# Fold 1 Accuracy: 0.987505784359093
# Fold 2 Accuracy: 0.982415548357242
# Fold 3 Accuracy: 0.982415548357242
# Fold 4 Accuracy: 0.98149005090236
# Classifier: KNeighborsClassifier(n_neighbors=2)
# Fold 0 Accuracy: 0.9824236817761333
# Fold 1 Accuracy: 0.985654789449329
# Fold 2 Accuracy: 0.977788061082832
# Fold 3 Accuracy: 0.980101804720037
# Fold 4 Accuracy: 0.9810273021749191
# Classifier: LinearSVC(random_state=777)
# Fold 0 Accuracy: 0.9791859389454209
# Fold 1 Accuracy: 0.979639055992596
# Fold 2 Accuracy: 0.971772327626099
# Fold 3 Accuracy: 0.9754743174456271
# Fold 4 Accuracy: 0.974086071263304
# ##############################################################
# DF: 3
# Classifier: DecisionTreeClassifier(random_state=777)
# Fold 0 Accuracy: 0.9895953757225433
# Fold 1 Accuracy: 0.9849710982658959
# Fold 2 Accuracy: 0.9837962962962963
# Fold 3 Accuracy: 0.9780092592592593
# Fold 4 Accuracy: 0.9849537037037037
# Classifier: RandomForestClassifier(random_state=777)
# Fold 0 Accuracy: 0.9907514450867052
# Fold 1 Accuracy: 0.9884393063583815
# Fold 2 Accuracy: 0.9884259259259259
# Fold 3 Accuracy: 0.9803240740740741
# Fold 4 Accuracy: 0.9872685185185185
# Classifier: KNeighborsClassifier(n_neighbors=2)
# Fold 0 Accuracy: 0.9884393063583815
# Fold 1 Accuracy: 0.9826589595375722
# Fold 2 Accuracy: 0.9872685185185185
# Fold 3 Accuracy: 0.9791666666666666
# Fold 4 Accuracy: 0.9803240740740741
# Classifier: LinearSVC(random_state=777)
# Fold 0 Accuracy: 0.9791907514450867
# Fold 1 Accuracy: 0.976878612716763
# Fold 2 Accuracy: 0.9849537037037037
# Fold 3 Accuracy: 0.9699074074074074
# Fold 4 Accuracy: 0.9722222222222222
# ##############################################################
# DF: 4
# Classifier: DecisionTreeClassifier(random_state=777)
# Fold 0 Accuracy: 0.9791666666666666
# Fold 1 Accuracy: 0.9930555555555556
# Fold 2 Accuracy: 0.9814814814814815
# Fold 3 Accuracy: 0.9791666666666666
# Fold 4 Accuracy: 0.988399071925754
# Classifier: RandomForestClassifier(random_state=777)
# Fold 0 Accuracy: 0.9837962962962963
# Fold 1 Accuracy: 0.9907407407407407
# Fold 2 Accuracy: 0.9814814814814815
# Fold 3 Accuracy: 0.9791666666666666
# Fold 4 Accuracy: 0.9953596287703016
# Classifier: KNeighborsClassifier(n_neighbors=2)
# Fold 0 Accuracy: 0.9791666666666666
# Fold 1 Accuracy: 0.9884259259259259
# Fold 2 Accuracy: 0.9791666666666666
# Fold 3 Accuracy: 0.9791666666666666
# Fold 4 Accuracy: 0.9930394431554525
# Classifier: LinearSVC(random_state=777)
# Fold 0 Accuracy: 0.9745370370370371
# Fold 1 Accuracy: 0.9814814814814815
# Fold 2 Accuracy: 0.9606481481481481
# Fold 3 Accuracy: 0.9745370370370371
# Fold 4 Accuracy: 0.9837587006960556

# %%
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.svm import LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, f1_score
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
import time

kfold_splits=5

skf = StratifiedKFold(n_splits=kfold_splits, shuffle=True, random_state=42)


DTClassifier = DecisionTreeClassifier(random_state=777)
RFClassifier = RandomForestClassifier(random_state=777)
KNNClassifier = KNeighborsClassifier()
SVMClassifier = LinearSVC(random_state=777)
classifiers = [DTClassifier, RFClassifier, KNNClassifier, SVMClassifier]

seq_lengths2 = [1, 2, 5, 10, 30]
dfs2 = []

for seq_length in seq_lengths2:
    df = pd.read_csv(f'csv/aggregated_time_{seq_length}s_df.csv')
    dfs2.append(df)

accuracies_per_classifier2 = [[0 for _ in dfs2] for _ in classifiers]
f1scores_per_classifier2 = [[0 for _ in dfs2] for _ in classifiers]
training_times_per_classifier2 = [[0 for _ in dfs2] for _ in classifiers]
prediction_times_per_classifier2 = [[0 for _ in dfs2] for _ in classifiers]

print("##############################################################")
print("              SEQUENZE PER TEMPO (NO HYDRA)                   ")
print("##############################################################")

for i in range(len(dfs2)):
    print("##############################################################")
    print(f"DF: {i}")

    aggregated_df = dfs2[i]
    labels = aggregated_df['label'].values
    X = aggregated_df.drop(columns=['label',])
    Y = aggregated_df['label']
    X = X.drop(columns=['avg_flow_number',])
    
    for j in range(len(classifiers)):

        classifier = classifiers[j]
        print(f"Classifier: {classifier}")
        
        accuracies = []
        f1scores = []
        training_times = []
        prediction_times=[]

        fold_iteration = 0
        for train_index, test_index in skf.split(X, Y):
            
            X_train, X_test = X.iloc[train_index], X.iloc[test_index]
            Y_train, Y_test = Y.iloc[train_index], Y.iloc[test_index]

            if(j>=2):
                scaler = MinMaxScaler()
                X_train = scaler.fit_transform(X_train)
                X_test = scaler.transform(X_test)
                X_train = pd.DataFrame(X_train, columns=X.columns)
                X_test = pd.DataFrame(X_test, columns=X.columns)
                if(j==2):
                    params = best_params[1][fold_iteration]
                    n = params['n_neighbors']
                    weight = params['weights']
                    classifier.set_params(n_neighbors=n, weights=weight)

            
            start = time.time()
            classifier.fit(X_train, Y_train)
            end = time.time()
            training_times.append(end-start)
            
            start = time.time()
            Y_pred = classifier.predict(X_test)
            end = time.time()
            prediction_times.append(end-start)
            
            acc = accuracy_score(Y_test, Y_pred)
            accuracies.append(acc)
            f1score = f1_score(Y_test, Y_pred, average='macro')
            f1scores.append(f1score)

            print(f"Fold {fold_iteration} Accuracy: {acc}")
            fold_iteration += 1
            
        accuracies_per_classifier2[j][i] = np.mean(accuracies)
        f1scores_per_classifier2[j][i] = np.mean(f1scores)
        training_times_per_classifier2[j][i] = np.mean(training_times)
        prediction_times_per_classifier2[j][i] = np.mean(prediction_times)
# Out:
# ##############################################################
#               SEQUENZE PER TEMPO (NO HYDRA)
# ##############################################################
# ##############################################################
# DF: 0
# Classifier: DecisionTreeClassifier(random_state=777)
# Fold 0 Accuracy: 0.8391708363116511
# Fold 1 Accuracy: 0.8420300214438885
# Fold 2 Accuracy: 0.8363116511794139
# Fold 3 Accuracy: 0.8498927805575411
# Fold 4 Accuracy: 0.8326180257510729
# Classifier: RandomForestClassifier(random_state=777)
# Fold 0 Accuracy: 0.8348820586132952
# Fold 1 Accuracy: 0.8484631879914224
# Fold 2 Accuracy: 0.8413152251608291
# Fold 3 Accuracy: 0.8470335954253038
# Fold 4 Accuracy: 0.8404864091559371
# Classifier: KNeighborsClassifier()
# Fold 0 Accuracy: 0.852037169406719
# Fold 1 Accuracy: 0.854181558255897
# Fold 2 Accuracy: 0.8355968548963545
# Fold 3 Accuracy: 0.8406004288777699
# Fold 4 Accuracy: 0.8326180257510729
# Classifier: LinearSVC(random_state=777)
# Fold 0 Accuracy: 0.775553967119371
# Fold 1 Accuracy: 0.7726947819871337
# Fold 2 Accuracy: 0.7684060042887777
# Fold 3 Accuracy: 0.7927090779127949
# Fold 4 Accuracy: 0.7646638054363376
# ##############################################################
# DF: 1
# Classifier: DecisionTreeClassifier(random_state=777)
# Fold 0 Accuracy: 0.8902777777777777
# Fold 1 Accuracy: 0.8762169680111266
# Fold 2 Accuracy: 0.9276773296244785
# Fold 3 Accuracy: 0.8706536856745479
# Fold 4 Accuracy: 0.8789986091794159
# Classifier: RandomForestClassifier(random_state=777)
# Fold 0 Accuracy: 0.9
# Fold 1 Accuracy: 0.874826147426982
# Fold 2 Accuracy: 0.9304589707927677
# Fold 3 Accuracy: 0.8734353268428373
# Fold 4 Accuracy: 0.8929068150208623
# Classifier: KNeighborsClassifier(n_neighbors=1)
# Fold 0 Accuracy: 0.8958333333333334
# Fold 1 Accuracy: 0.885952712100139
# Fold 2 Accuracy: 0.913769123783032
# Fold 3 Accuracy: 0.8553546592489569
# Fold 4 Accuracy: 0.8734353268428373
# Classifier: LinearSVC(random_state=777)
# Fold 0 Accuracy: 0.7819444444444444
# Fold 1 Accuracy: 0.7830319888734353
# Fold 2 Accuracy: 0.780250347705146
# Fold 3 Accuracy: 0.7190542420027817
# Fold 4 Accuracy: 0.7287899860917941
# ##############################################################
# DF: 2
# Classifier: DecisionTreeClassifier(random_state=777)
# Fold 0 Accuracy: 0.9270833333333334
# Fold 1 Accuracy: 0.9128919860627178
# Fold 2 Accuracy: 0.9163763066202091
# Fold 3 Accuracy: 0.9128919860627178
# Fold 4 Accuracy: 0.9303135888501742
# Classifier: RandomForestClassifier(random_state=777)
# Fold 0 Accuracy: 0.9305555555555556
# Fold 1 Accuracy: 0.9372822299651568
# Fold 2 Accuracy: 0.9198606271777003
# Fold 3 Accuracy: 0.9337979094076655
# Fold 4 Accuracy: 0.9442508710801394
# Classifier: KNeighborsClassifier(n_neighbors=1)
# Fold 0 Accuracy: 0.8854166666666666
# Fold 1 Accuracy: 0.926829268292683
# Fold 2 Accuracy: 0.8885017421602788
# Fold 3 Accuracy: 0.9233449477351916
# Fold 4 Accuracy: 0.9233449477351916
# Classifier: LinearSVC(random_state=777)
# Fold 0 Accuracy: 0.7638888888888888
# Fold 1 Accuracy: 0.7421602787456446
# Fold 2 Accuracy: 0.7212543554006968
# Fold 3 Accuracy: 0.7560975609756098
# Fold 4 Accuracy: 0.7073170731707317
# ##############################################################
# DF: 3
# Classifier: DecisionTreeClassifier(random_state=777)
# Fold 0 Accuracy: 0.9375
# Fold 1 Accuracy: 0.9300699300699301
# Fold 2 Accuracy: 0.972027972027972
# Fold 3 Accuracy: 0.951048951048951
# Fold 4 Accuracy: 0.9020979020979021
# Classifier: RandomForestClassifier(random_state=777)
# Fold 0 Accuracy: 0.9236111111111112
# Fold 1 Accuracy: 0.9370629370629371
# Fold 2 Accuracy: 0.972027972027972
# Fold 3 Accuracy: 0.9090909090909091
# Fold 4 Accuracy: 0.9020979020979021
# Classifier: KNeighborsClassifier(n_neighbors=1)
# Fold 0 Accuracy: 0.875
# Fold 1 Accuracy: 0.8461538461538461
# Fold 2 Accuracy: 0.9440559440559441
# Fold 3 Accuracy: 0.8531468531468531
# Fold 4 Accuracy: 0.8041958041958042
# Classifier: LinearSVC(random_state=777)
# Fold 0 Accuracy: 0.75
# Fold 1 Accuracy: 0.7202797202797203
# Fold 2 Accuracy: 0.7902097902097902
# Fold 3 Accuracy: 0.7132867132867133
# Fold 4 Accuracy: 0.6993006993006993
# ##############################################################
# DF: 4
# Classifier: DecisionTreeClassifier(random_state=777)
# Fold 0 Accuracy: 0.9583333333333334
# Fold 1 Accuracy: 0.9574468085106383
# Fold 2 Accuracy: 0.9574468085106383
# Fold 3 Accuracy: 0.9361702127659575
# Fold 4 Accuracy: 0.9361702127659575
# Classifier: RandomForestClassifier(random_state=777)
# Fold 0 Accuracy: 0.9791666666666666
# Fold 1 Accuracy: 0.9361702127659575
# Fold 2 Accuracy: 0.9574468085106383
# Fold 3 Accuracy: 0.9574468085106383
# Fold 4 Accuracy: 0.9361702127659575
# Classifier: KNeighborsClassifier(n_neighbors=1)
# Fold 0 Accuracy: 0.6458333333333334
# Fold 1 Accuracy: 0.9361702127659575
# Fold 2 Accuracy: 0.8936170212765957
# Fold 3 Accuracy: 0.9148936170212766
# Fold 4 Accuracy: 0.9148936170212766
# Classifier: LinearSVC(random_state=777)
# Fold 0 Accuracy: 0.7291666666666666
# Fold 1 Accuracy: 0.8085106382978723
# Fold 2 Accuracy: 0.7872340425531915
# Fold 3 Accuracy: 0.7659574468085106
# Fold 4 Accuracy: 0.723404255319149

# %%
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.svm import SVC
from sklearn.svm import LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, f1_score
import matplotlib.pyplot as plt
import torch
import pandas as pd
import seaborn as sns
import numpy as np
import time

kfold_splits=5

skf = StratifiedKFold(n_splits=kfold_splits, shuffle=True, random_state=42)


DTClassifier = DecisionTreeClassifier(random_state=777)
RFClassifier = RandomForestClassifier(random_state=777)
KNNClassifier = KNeighborsClassifier(n_neighbors=50)
SVMClassifier = LinearSVC(random_state=777, dual=False)
classifiers = [DTClassifier, RFClassifier, KNNClassifier, SVMClassifier]

seq_lengths3 = [10, 50, 100, 250, 500]
dfs3 = []

for seq_length in seq_lengths3:
    df = pd.read_csv(f'csv/aggregated_{seq_length}packets_df.csv')
    dfs3.append(df)

accuracies_per_classifier3 = [[0 for _ in dfs3] for _ in classifiers]
f1scores_per_classifier3 = [[0 for _ in dfs3] for _ in classifiers]
training_times_per_classifier3 = [[0 for _ in dfs3] for _ in classifiers]
prediction_times_per_classifier3= [[0 for _ in dfs3] for _ in classifiers]

print("##############################################################")
print("              SEQUENZE PER PACCHETTI (HYDRA)                  ")
print("##############################################################")

for i in range(len(dfs3)):
    print("##############################################################")
    print(f"DF: {i}")

    aggregated_df = dfs3[i]

    features = [
    'byte_rate', 'packet_rate', 'avg_deltatime',
    'source_entropy', 'destination_entropy', 's-port_entropy',
    'd-port_entropy', 'synack_ratio', 'modbus_rate', 'tcp_rate',
    'ping_rate', 'other_rate'
    ]

    hydra_seq_length = 10
    hydra_window_slide = hydra_seq_length
    feature_sequences = [create_sequences(aggregated_df[feature].values, hydra_seq_length, hydra_window_slide) for feature in features]
    
    sequences_tensor = torch.tensor(np.stack(feature_sequences, axis=1), dtype=torch.float32)
    
    labels = aggregated_df['label'].values
    labels_seq = create_sequences(labels, hydra_seq_length, hydra_window_slide)
    labels_tensor = torch.tensor(labels_seq[:, -1], dtype=torch.long)
    
    for j in range(len(classifiers)):

        classifier = classifiers[j]
        print(f"Classifier: {classifier}")
        
        
        accuracies = []
        f1scores = []
        training_times = []
        prediction_times=[]

        fold_iteration = 0
        for train_index, test_index in skf.split(sequences_tensor, labels_tensor):
            X_train, X_test = sequences_tensor[train_index], sequences_tensor[test_index]
            Y_train, Y_test = labels_tensor[train_index], labels_tensor[test_index]

            hydra_multivariate = HydraMultivariate(input_length=seq_length, num_channels=4)
            
            X_train_transform = hydra_multivariate.batch(X_train)
            X_test_transform = hydra_multivariate.batch(X_test)

            scaler = SparseScaler()
            X_train_transform = scaler.fit_transform(X_train_transform)
            X_test_transform = scaler.transform(X_test_transform)

            if(j>=2):
                min_max_scaler = MinMaxScaler()
                X_train_transform = min_max_scaler.fit_transform(X_train_transform)
                X_test_transform = min_max_scaler.transform(X_test_transform)
                if(j==2):
                    params = best_params[2][fold_iteration]
                    n = params['n_neighbors']
                    weight = params['weights']
                    classifier.set_params(n_neighbors=n, weights=weight)
            
            start = time.time()
            classifier.fit(X_train_transform, Y_train)
            end = time.time()
            training_times.append(end-start)
            
            start = time.time()
            Y_pred = classifier.predict(X_test_transform)
            end = time.time()
            prediction_times.append(end-start)
            
            acc = accuracy_score(Y_test, Y_pred)
            accuracies.append(acc)
            f1score = f1_score(Y_test, Y_pred, average='macro')
            f1scores.append(f1score)

            print(f"Fold {fold_iteration} Accuracy: {acc}")
            fold_iteration += 1
            
        accuracies_per_classifier3[j][i] = np.mean(accuracies)
        f1scores_per_classifier3[j][i] = np.mean(f1scores)
        training_times_per_classifier3[j][i] = np.mean(training_times)
        prediction_times_per_classifier3[j][i] = np.mean(prediction_times)
# Out:
# ##############################################################
#               SEQUENZE PER PACCHETTI (HYDRA)
# ##############################################################
# ##############################################################
# DF: 0
# Classifier: DecisionTreeClassifier(random_state=777)
# Fold 0 Accuracy: 0.9634597594819612
# Fold 1 Accuracy: 0.9717853839037928
# Fold 2 Accuracy: 0.961129106894956
# Fold 3 Accuracy: 0.965756594169366
# Fold 4 Accuracy: 0.96298010180472
# Classifier: RandomForestClassifier(random_state=777)
# Fold 0 Accuracy: 0.9740980573543015
# Fold 1 Accuracy: 0.9777983348751156
# Fold 2 Accuracy: 0.968070337806571
# Fold 3 Accuracy: 0.973160573808422
# Fold 4 Accuracy: 0.971772327626099
# Classifier: KNeighborsClassifier(n_neighbors=50)
# Fold 0 Accuracy: 0.8709528214616096
# Fold 1 Accuracy: 0.8765032377428307
# Fold 2 Accuracy: 0.8634891254049052
# Fold 3 Accuracy: 0.8551596483109671
# Fold 4 Accuracy: 0.8667283664969921
# Classifier: LinearSVC(dual=False, random_state=777)
# Fold 0 Accuracy: 0.9135060129509713
# Fold 1 Accuracy: 0.9213691026827012
# Fold 2 Accuracy: 0.9134659879685331
# Fold 3 Accuracy: 0.9213327163350301
# Fold 4 Accuracy: 0.912540490513651
# ##############################################################
# DF: 1
# Classifier: DecisionTreeClassifier(random_state=777)
# Fold 0 Accuracy: 0.9792147806004619
# Fold 1 Accuracy: 0.9884259259259259
# Fold 2 Accuracy: 0.9768518518518519
# Fold 3 Accuracy: 0.9791666666666666
# Fold 4 Accuracy: 0.9884259259259259
# Classifier: RandomForestClassifier(random_state=777)
# Fold 0 Accuracy: 0.9745958429561201
# Fold 1 Accuracy: 0.9884259259259259
# Fold 2 Accuracy: 0.9699074074074074
# Fold 3 Accuracy: 0.9791666666666666
# Fold 4 Accuracy: 0.9930555555555556
# Classifier: KNeighborsClassifier(n_neighbors=2)
# Fold 0 Accuracy: 0.9422632794457275
# Fold 1 Accuracy: 0.9467592592592593
# Fold 2 Accuracy: 0.9490740740740741
# Fold 3 Accuracy: 0.9490740740740741
# Fold 4 Accuracy: 0.9629629629629629
# Classifier: LinearSVC(dual=False, random_state=777)
# Fold 0 Accuracy: 0.9607390300230947
# Fold 1 Accuracy: 0.9699074074074074
# Fold 2 Accuracy: 0.9513888888888888
# Fold 3 Accuracy: 0.9722222222222222
# Fold 4 Accuracy: 0.9814814814814815
# ##############################################################
# DF: 2
# Classifier: DecisionTreeClassifier(random_state=777)
# Fold 0 Accuracy: 0.9768518518518519
# Fold 1 Accuracy: 0.9629629629629629
# Fold 2 Accuracy: 0.9768518518518519
# Fold 3 Accuracy: 0.9814814814814815
# Fold 4 Accuracy: 0.9814814814814815
# Classifier: RandomForestClassifier(random_state=777)
# Fold 0 Accuracy: 0.9953703703703703
# Fold 1 Accuracy: 0.9722222222222222
# Fold 2 Accuracy: 0.9861111111111112
# Fold 3 Accuracy: 0.9907407407407407
# Fold 4 Accuracy: 0.9814814814814815
# Classifier: KNeighborsClassifier(n_neighbors=2)
# Fold 0 Accuracy: 0.9444444444444444
# Fold 1 Accuracy: 0.9351851851851852
# Fold 2 Accuracy: 0.9675925925925926
# Fold 3 Accuracy: 0.9490740740740741
# Fold 4 Accuracy: 0.9629629629629629
# Classifier: LinearSVC(dual=False, random_state=777)
# Fold 0 Accuracy: 0.9814814814814815
# Fold 1 Accuracy: 0.9629629629629629
# Fold 2 Accuracy: 0.9814814814814815
# Fold 3 Accuracy: 0.9722222222222222
# Fold 4 Accuracy: 0.9629629629629629
# ##############################################################
# DF: 3
# Classifier: DecisionTreeClassifier(random_state=777)
# Fold 0 Accuracy: 0.9770114942528736
# Fold 1 Accuracy: 0.9770114942528736
# Fold 2 Accuracy: 0.9302325581395349
# Fold 3 Accuracy: 0.9651162790697675
# Fold 4 Accuracy: 0.9883720930232558
# Classifier: RandomForestClassifier(random_state=777)
# Fold 0 Accuracy: 0.9425287356321839
# Fold 1 Accuracy: 0.9885057471264368
# Fold 2 Accuracy: 0.9651162790697675
# Fold 3 Accuracy: 0.9767441860465116
# Fold 4 Accuracy: 1.0
# Classifier: KNeighborsClassifier(n_neighbors=2)
# Fold 0 Accuracy: 0.896551724137931
# Fold 1 Accuracy: 0.9655172413793104
# Fold 2 Accuracy: 0.9418604651162791
# Fold 3 Accuracy: 0.9651162790697675
# Fold 4 Accuracy: 0.9767441860465116
# Classifier: LinearSVC(dual=False, random_state=777)
# Fold 0 Accuracy: 0.9425287356321839
# Fold 1 Accuracy: 0.9885057471264368
# Fold 2 Accuracy: 0.9651162790697675
# Fold 3 Accuracy: 0.9651162790697675
# Fold 4 Accuracy: 0.9767441860465116
# ##############################################################
# DF: 4
# Classifier: DecisionTreeClassifier(random_state=777)
# Fold 0 Accuracy: 0.9534883720930233
# Fold 1 Accuracy: 0.9767441860465116
# Fold 2 Accuracy: 0.9302325581395349
# Fold 3 Accuracy: 0.9534883720930233
# Fold 4 Accuracy: 0.9767441860465116
# Classifier: RandomForestClassifier(random_state=777)
# Fold 0 Accuracy: 1.0
# Fold 1 Accuracy: 0.9534883720930233
# Fold 2 Accuracy: 0.9534883720930233
# Fold 3 Accuracy: 0.9534883720930233
# Fold 4 Accuracy: 1.0
# Classifier: KNeighborsClassifier(n_neighbors=2)
# Fold 0 Accuracy: 0.9302325581395349
# Fold 1 Accuracy: 0.9767441860465116
# Fold 2 Accuracy: 0.9069767441860465
# Fold 3 Accuracy: 0.9302325581395349
# Fold 4 Accuracy: 1.0
# Classifier: LinearSVC(dual=False, random_state=777)
# Fold 0 Accuracy: 1.0
# Fold 1 Accuracy: 0.9767441860465116
# Fold 2 Accuracy: 0.9534883720930233
# Fold 3 Accuracy: 0.9767441860465116
# Fold 4 Accuracy: 1.0

# %%
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.svm import LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, f1_score
import matplotlib.pyplot as plt
import torch
import pandas as pd
import seaborn as sns
import numpy as np
import time

kfold_splits=5

skf = StratifiedKFold(n_splits=kfold_splits, shuffle=True, random_state=42)


DTClassifier = DecisionTreeClassifier(random_state=777)
RFClassifier = RandomForestClassifier(random_state=777)
KNNClassifier = KNeighborsClassifier(n_neighbors=9)
SVMClassifier = LinearSVC(random_state=777, dual=False)
classifiers = [DTClassifier, RFClassifier, KNNClassifier, SVMClassifier]

seq_lengths4 = [1, 2, 5, 10, 30]
dfs4 = []

for seq_length in seq_lengths4:
    df = pd.read_csv(f'csv/aggregated_time_{seq_length}s_df.csv')
    dfs4.append(df)

accuracies_per_classifier4 = [[0 for _ in dfs4] for _ in classifiers]
f1scores_per_classifier4 = [[0 for _ in dfs4] for _ in classifiers]
training_times_per_classifier4 = [[0 for _ in dfs4] for _ in classifiers]
prediction_times_per_classifier4= [[0 for _ in dfs4] for _ in classifiers]

print("##############################################################")
print("              SEQUENZE PER TEMPO (HYDRA)                   ")
print("##############################################################")

for i in range(len(dfs4)):
    print("##############################################################")
    print(f"DF: {i}")

    aggregated_df = dfs4[i]

    features = [
    'byte_rate', 'packet_rate', 'avg_deltatime',
    'source_entropy', 'destination_entropy', 's-port_entropy',
    'd-port_entropy', 'synack_ratio', 'modbus_rate', 'tcp_rate',
    'ping_rate', 'other_rate'
    ]

    hydra_seq_length = 10
    hydra_window_slide = int(1)
    feature_sequences = [create_sequences(aggregated_df[feature].values, hydra_seq_length, hydra_window_slide) for feature in features]
    
    sequences_tensor = torch.tensor(np.stack(feature_sequences, axis=1), dtype=torch.float32)
    
    labels = aggregated_df['label'].values
    labels_seq = create_sequences(labels, hydra_seq_length, hydra_window_slide)
    labels_tensor = torch.tensor(labels_seq[:, -1], dtype=torch.long)  # Use the last element of each sequence as the label
    
    for j in range(len(classifiers)):

        classifier = classifiers[j]
        print(f"Classifier: {classifier}")
        
        
        accuracies = []
        f1scores = []
        training_times = []
        prediction_times=[]

        fold_iteration = 0
        for train_index, test_index in skf.split(sequences_tensor, labels_tensor):
            X_train, X_test = sequences_tensor[train_index], sequences_tensor[test_index]
            Y_train, Y_test = labels_tensor[train_index], labels_tensor[test_index]

            hydra_multivariate = HydraMultivariate(input_length=seq_length, num_channels=4)

            X_train_transform = hydra_multivariate.batch(X_train)
            X_test_transform = hydra_multivariate.batch(X_test)

            scaler = SparseScaler()
            X_train_transform = scaler.fit_transform(X_train_transform)
            X_test_transform = scaler.transform(X_test_transform)

            if(j>=2):
                min_max_scaler = MinMaxScaler()
                X_train_transform = min_max_scaler.fit_transform(X_train_transform)
                X_test_transform = min_max_scaler.transform(X_test_transform)
                if(j==2):
                        params = best_params[3][fold_iteration]
                        n = params['n_neighbors']
                        weight = params['weights']
                        classifier.set_params(n_neighbors=n, weights=weight)
            
            start = time.time()
            classifier.fit(X_train_transform, Y_train)
            end = time.time()
            training_times.append(end-start)
            
            start = time.time()
            Y_pred = classifier.predict(X_test_transform)
            end = time.time()
            prediction_times.append(end-start)
            
            acc = accuracy_score(Y_test, Y_pred)
            accuracies.append(acc)
            f1score = f1_score(Y_test, Y_pred, average='macro')
            f1scores.append(f1score)

            print(f"Fold {fold_iteration} Accuracy: {acc}")
            fold_iteration += 1
            
        accuracies_per_classifier4[j][i] = np.mean(accuracies)
        f1scores_per_classifier4[j][i] = np.mean(f1scores)
        training_times_per_classifier4[j][i] = np.mean(training_times)
        prediction_times_per_classifier4[j][i] = np.mean(prediction_times)
# Out:
# ##############################################################
#               SEQUENZE PER TEMPO (HYDRA)
# ##############################################################
# ##############################################################
# DF: 0
# Classifier: DecisionTreeClassifier(random_state=777)
# Fold 0 Accuracy: 0.9241231209735147
# Fold 1 Accuracy: 0.9312813171080888
# Fold 2 Accuracy: 0.9284180386542591
# Fold 3 Accuracy: 0.9319971367215462
# Fold 4 Accuracy: 0.9312813171080888
# Classifier: RandomForestClassifier(random_state=777)
# Fold 0 Accuracy: 0.9556191839656406
# Fold 1 Accuracy: 0.9563350035790981
# Fold 2 Accuracy: 0.9642090193271295
# Fold 3 Accuracy: 0.9627773801002147
# Fold 4 Accuracy: 0.9556191839656406
# Classifier: KNeighborsClassifier(n_neighbors=9)
# Fold 0 Accuracy: 0.9133858267716536
# Fold 1 Accuracy: 0.8647100930565498
# Fold 2 Accuracy: 0.8947745168217609
# Fold 3 Accuracy: 0.905511811023622
# Fold 4 Accuracy: 0.8926270579813886
# Classifier: LinearSVC(dual=False, random_state=777)
# Fold 0 Accuracy: 0.9098067287043665
# Fold 1 Accuracy: 0.917680744452398
# Fold 2 Accuracy: 0.9305654974946314
# Fold 3 Accuracy: 0.9298496778811739
# Fold 4 Accuracy: 0.9105225483178239
# ##############################################################
# DF: 1
# Classifier: DecisionTreeClassifier(random_state=777)
# Fold 0 Accuracy: 0.967966573816156
# Fold 1 Accuracy: 0.9665738161559888
# Fold 2 Accuracy: 0.9511854951185496
# Fold 3 Accuracy: 0.9525801952580195
# Fold 4 Accuracy: 0.9483960948396095
# Classifier: RandomForestClassifier(random_state=777)
# Fold 0 Accuracy: 0.9832869080779945
# Fold 1 Accuracy: 0.9735376044568245
# Fold 2 Accuracy: 0.9804741980474198
# Fold 3 Accuracy: 0.9707112970711297
# Fold 4 Accuracy: 0.9818688981868898
# Classifier: KNeighborsClassifier(n_neighbors=4, weights='distance')
# Fold 0 Accuracy: 0.8774373259052924
# Fold 1 Accuracy: 0.8607242339832869
# Fold 2 Accuracy: 0.8675034867503487
# Fold 3 Accuracy: 0.8507670850767085
# Fold 4 Accuracy: 0.8605299860529986
# Classifier: LinearSVC(dual=False, random_state=777)
# Fold 0 Accuracy: 0.8746518105849582
# Fold 1 Accuracy: 0.8969359331476323
# Fold 2 Accuracy: 0.895397489539749
# Fold 3 Accuracy: 0.8926080892608089
# Fold 4 Accuracy: 0.891213389121339
# ##############################################################
# DF: 2
# Classifier: DecisionTreeClassifier(random_state=777)
# Fold 0 Accuracy: 0.951048951048951
# Fold 1 Accuracy: 0.951048951048951
# Fold 2 Accuracy: 0.9263157894736842
# Fold 3 Accuracy: 0.9719298245614035
# Fold 4 Accuracy: 0.9754385964912281
# Classifier: RandomForestClassifier(random_state=777)
# Fold 0 Accuracy: 0.9825174825174825
# Fold 1 Accuracy: 0.9895104895104895
# Fold 2 Accuracy: 0.9614035087719298
# Fold 3 Accuracy: 0.9894736842105263
# Fold 4 Accuracy: 0.9754385964912281
# Classifier: KNeighborsClassifier(n_neighbors=4, weights='distance')
# Fold 0 Accuracy: 0.8811188811188811
# Fold 1 Accuracy: 0.8146853146853147
# Fold 2 Accuracy: 0.7789473684210526
# Fold 3 Accuracy: 0.8175438596491228
# Fold 4 Accuracy: 0.8421052631578947
# Classifier: LinearSVC(dual=False, random_state=777)
# Fold 0 Accuracy: 0.9265734265734266
# Fold 1 Accuracy: 0.8916083916083916
# Fold 2 Accuracy: 0.9052631578947369
# Fold 3 Accuracy: 0.9333333333333333
# Fold 4 Accuracy: 0.9122807017543859
# ##############################################################
# DF: 3
# Classifier: DecisionTreeClassifier(random_state=777)
# Fold 0 Accuracy: 0.9225352112676056
# Fold 1 Accuracy: 0.9014084507042254
# Fold 2 Accuracy: 0.9290780141843972
# Fold 3 Accuracy: 0.9290780141843972
# Fold 4 Accuracy: 0.9432624113475178
# Classifier: RandomForestClassifier(random_state=777)
# Fold 0 Accuracy: 0.9507042253521126
# Fold 1 Accuracy: 0.9295774647887324
# Fold 2 Accuracy: 0.9574468085106383
# Fold 3 Accuracy: 0.9432624113475178
# Fold 4 Accuracy: 0.9645390070921985
# Classifier: KNeighborsClassifier(n_neighbors=4, weights='distance')
# Fold 0 Accuracy: 0.7746478873239436
# Fold 1 Accuracy: 0.7535211267605634
# Fold 2 Accuracy: 0.7092198581560284
# Fold 3 Accuracy: 0.7021276595744681
# Fold 4 Accuracy: 0.6950354609929078
# Classifier: LinearSVC(dual=False, random_state=777)
# Fold 0 Accuracy: 0.9295774647887324
# Fold 1 Accuracy: 0.9014084507042254
# Fold 2 Accuracy: 0.9148936170212766
# Fold 3 Accuracy: 0.9361702127659575
# Fold 4 Accuracy: 0.9219858156028369
# ##############################################################
# DF: 4
# Classifier: DecisionTreeClassifier(random_state=777)
# Fold 0 Accuracy: 0.8043478260869565
# Fold 1 Accuracy: 0.8695652173913043
# Fold 2 Accuracy: 0.9111111111111111
# Fold 3 Accuracy: 0.8888888888888888
# Fold 4 Accuracy: 0.8222222222222222
# Classifier: RandomForestClassifier(random_state=777)
# Fold 0 Accuracy: 0.8913043478260869
# Fold 1 Accuracy: 0.9565217391304348
# Fold 2 Accuracy: 0.9333333333333333
# Fold 3 Accuracy: 0.8666666666666667
# Fold 4 Accuracy: 0.9333333333333333
# Classifier: KNeighborsClassifier(n_neighbors=4, weights='distance')
# Fold 0 Accuracy: 0.717391304347826
# Fold 1 Accuracy: 0.7608695652173914
# Fold 2 Accuracy: 0.8444444444444444
# Fold 3 Accuracy: 0.7777777777777778
# Fold 4 Accuracy: 0.8222222222222222
# Classifier: LinearSVC(dual=False, random_state=777)
# Fold 0 Accuracy: 0.8695652173913043
# Fold 1 Accuracy: 0.9565217391304348
# Fold 2 Accuracy: 0.8888888888888888
# Fold 3 Accuracy: 0.9111111111111111
# Fold 4 Accuracy: 0.9555555555555556

# %%
plt.rcParams.update({
    'font.size': 16,               # Default font size for text elements (titles, labels, etc.)
    'axes.labelsize': 16,          # Font size for x and y axis labels
    'axes.titlesize': 15,          # Font size for axis titles
    'xtick.labelsize': 16,         # Font size for x-axis tick labels
    'ytick.labelsize': 16,         # Font size for y-axis tick labels
    'legend.fontsize': 13,         # Font size for legend
})

# %%
plt.figure(figsize=(8, 6))

clf_names = ['DT', 'RF', 'KNN', 'SVC']
colors = ['blue', 'orange', 'red', 'green']

for i in range(len(classifiers)):
    plt.plot(seq_lengths1, accuracies_per_classifier1[i], label=f'{clf_names[i]} Accuracy', color = colors[i], linestyle='-', marker='o')
    plt.plot(seq_lengths1, f1scores_per_classifier1[i], label=f'{clf_names[i]} F1-Score', color = colors[i], linestyle='--', marker='x')

plt.xlabel('Sequence Length (pacchetti)')
plt.ylabel('Scores')
plt.title('Accuracy e F1-Score (Sequenze per pacchetti - No HYDRA)')
plt.ylim(top=1)
plt.grid(True)
plt.savefig('images/packets_classifier.pdf')
plt.show()

# %%
plt.figure(figsize=(8, 6))

clf_names = ['DT', 'RF', 'KNN', 'SVC']
colors = ['blue', 'orange', 'red', 'green']

for i in range(len(classifiers)):
    plt.plot(seq_lengths2, accuracies_per_classifier2[i], label=f'{clf_names[i]} Accuracy', color = colors[i], linestyle='-', marker='o')
    plt.plot(seq_lengths2, f1scores_per_classifier2[i], label=f'{clf_names[i]} F1-Score', color = colors[i], linestyle='--', marker='x')

plt.xlabel('Sequence Length (secondi)', fontsize=14)
plt.ylabel('Scores', fontsize=14)
plt.title('Accuracy e F1-Score (Sequenze per tempo - No HYDRA)', fontsize=14)
plt.legend(fontsize=14)
plt.ylim(top=1)
plt.grid(True)
plt.savefig('images/time_classifier.pdf')
plt.show()

# %%
plt.figure(figsize=(8, 6))

clf_names = ['DT', 'RF', 'KNN', 'SVC']
colors = ['blue', 'orange', 'red', 'green']

for i in range(len(classifiers)):
    plt.plot(seq_lengths3, accuracies_per_classifier3[i], label=f'{clf_names[i]} Accuracy', color = colors[i], linestyle='-', marker='o')
    plt.plot(seq_lengths3, f1scores_per_classifier3[i], label=f'{clf_names[i]} F1-Score', color = colors[i], linestyle='--', marker='x')

plt.xlabel('Sequence Length (secondi)')
plt.ylabel('Scores')
plt.title('Accuracy e F1-Score (Sequenze per pacchetti - HYDRA)')
plt.legend()
plt.ylim(top=1)
plt.grid(True)
plt.savefig('images/packets_classifier_hydra.pdf')
plt.show()

# %%
plt.figure(figsize=(8, 6))

clf_names = ['DT', 'RF', 'KNN', 'SVC']
colors = ['blue', 'orange', 'red', 'green']

for i in range(len(classifiers)):
    plt.plot(seq_lengths4, accuracies_per_classifier4[i], label=f'{clf_names[i]} Accuracy', color = colors[i], linestyle='-', marker='o')
    plt.plot(seq_lengths4, f1scores_per_classifier4[i], label=f'{clf_names[i]} F1-Score', color = colors[i], linestyle='--', marker='x')

plt.xlabel('Sequence Length (secondi)')
plt.ylabel('Scores')
plt.title('Accuracy e F1-Score (Sequenze per tempo - HYDRA)')
plt.legend()
plt.ylim(top=1)
plt.grid(True)
plt.savefig('images/time_classifier_hydra.pdf')
plt.show()

# %%
plt.figure(figsize=(8, 6))

clf_names = ['DT', 'RF', 'KNN', 'SVC']
colors = ['blue', 'orange', 'red', 'green']

for i in range(len(classifiers)):
    plt.plot(seq_lengths1, accuracies_per_classifier1[i], label=f'{clf_names[i]} Accuracy Regular', color = colors[i], linestyle='-', marker='o')
    plt.plot(seq_lengths3, accuracies_per_classifier3[i], label=f'{clf_names[i]} Accuracy HYDRA', color = colors[i], linestyle='--', marker='x')

plt.xlabel('Sequence Length (pacchetti)')
plt.ylabel('Scores')
plt.title('Accuracy (Sequenze per pacchetti)')
plt.legend()
plt.ylim(top=1)
plt.grid(True)
plt.savefig('images/packets_accuracy_comparison.pdf')
plt.show()

# %%
plt.figure(figsize=(8, 6))

clf_names = ['DT', 'RF', 'KNN', 'SVC']
colors = ['blue', 'orange', 'red', 'green']

for i in range(len(classifiers)):
    plt.plot(seq_lengths1, f1scores_per_classifier1[i], label=f'{clf_names[i]} F1-Score Regular', color = colors[i], linestyle='-', marker='o')
    plt.plot(seq_lengths3, f1scores_per_classifier3[i], label=f'{clf_names[i]} F1-Score HYDRA', color = colors[i], linestyle='--', marker='x')

plt.xlabel('Sequence Length (pacchetti)')
plt.ylabel('Scores')
plt.title('F1-Score (Sequenze per pacchetti)')
plt.legend()
plt.ylim(top=1)
plt.grid(True)
plt.savefig('images/packets_f1score_comparison.pdf')
plt.show()

# %%
plt.figure(figsize=(8, 6))

clf_names = ['DT', 'RF', 'KNN', 'SVC']
colors = ['blue', 'orange', 'red', 'green']

for i in range(len(classifiers)):
    plt.plot(seq_lengths2, accuracies_per_classifier2[i], label=f'{clf_names[i]} Accuracy Regular', color = colors[i], linestyle='-', marker='o')
    plt.plot(seq_lengths4, accuracies_per_classifier4[i], label=f'{clf_names[i]} Accuracy HYDRA', color = colors[i], linestyle='--', marker='x')

plt.xlabel('Sequence Length (tempo)')
plt.ylabel('Scores')
plt.title('Accuracy (Sequenze per tempo)')
plt.legend()
plt.ylim(top=1)
plt.grid(True)
plt.savefig('images/time_accuracy_comparison.pdf')
plt.show()

# %%
plt.figure(figsize=(8, 6))

clf_names = ['DT', 'RF', 'KNN', 'SVC']
colors = ['blue', 'orange', 'red', 'green']

for i in range(len(classifiers)):
    plt.plot(seq_lengths2, f1scores_per_classifier2[i], label=f'{clf_names[i]} F1-Score Regular', color = colors[i], linestyle='-', marker='o')
    plt.plot(seq_lengths4, f1scores_per_classifier4[i], label=f'{clf_names[i]} F1-Score HYDRA', color = colors[i], linestyle='--', marker='x')

plt.xlabel('Sequence Length (tempo)')
plt.ylabel('Scores')
plt.title('F1-Score (Sequenze per tempo)')
plt.legend()
plt.ylim(top=1)
plt.grid(True)
plt.savefig('images/time_f1score_comparison.pdf')
plt.show()

# %%
plt.figure(figsize=(8, 6))

clf_names = ['DT', 'RF', 'KNN', 'SVC']
colors = ['blue', 'orange', 'red', 'green']



for i in range(len(classifiers)):
    plt.plot(seq_lengths1, prediction_times_per_classifier1[i], label=f'{clf_names[i]} Regular', color = colors[i], linestyle='-', marker='o')
    plt.plot(seq_lengths3, prediction_times_per_classifier3[i], label=f'{clf_names[i]} HYDRA', color = colors[i], linestyle='--', marker='o')

plt.xlabel('Sequence Length (pacchetti)')
plt.ylabel('Secondi')
plt.yscale('log')
plt.title('Tempo di classificazione')
plt.legend()
plt.grid(True)
plt.savefig('images/tempi_class_pacchetti.pdf')
plt.show()

# %%
plt.figure(figsize=(8, 6))

clf_names = ['DT', 'RF', 'KNN', 'SVC']
colors = ['blue', 'orange', 'red', 'green']

for i in range(len(classifiers)):
    plt.plot(seq_lengths2, prediction_times_per_classifier2[i], label=f'{clf_names[i]} Regular', color = colors[i], linestyle='-', marker='o')
    plt.plot(seq_lengths4, prediction_times_per_classifier4[i], label=f'{clf_names[i]} HYDRA', color = colors[i], linestyle='--', marker='o')

plt.xlabel('Sequence Length (secondi)')
plt.ylabel('Secondi')
plt.yscale('log')
plt.title('Tempo di classificazione')
plt.legend()
plt.grid(True)
plt.savefig('images/tempi_class_secondi.pdf')
plt.show()

# %%
plt.figure(figsize=(8, 6))

clf_names = ['DT', 'RF', 'KNN', 'SVC']
colors = ['blue', 'orange', 'red', 'green']


for i in range(len(classifiers)):
    plt.plot(seq_lengths1, training_times_per_classifier1[i], label=f'{clf_names[i]} Regular', color = colors[i], linestyle='-', marker='o')
    plt.plot(seq_lengths3, training_times_per_classifier3[i], label=f'{clf_names[i]} HYDRA', color = colors[i], linestyle='--', marker='o')

plt.xlabel('Sequence Length (pacchetti)')
plt.ylabel('Secondi')
plt.yscale('log')
plt.title('Tempo di training')
plt.legend()
plt.grid(True)
plt.savefig('images/tempi_training_pacchetti.pdf')
plt.show()

# %%
plt.figure(figsize=(8, 6))

clf_names = ['DT', 'RF', 'KNN', 'SVC']
colors = ['blue', 'orange', 'red', 'green']


for i in range(len(classifiers)):
    plt.plot(seq_lengths2, training_times_per_classifier2[i], label=f'{clf_names[i]} Regular', color = colors[i], linestyle='-', marker='o')
    plt.plot(seq_lengths4, training_times_per_classifier4[i], label=f'{clf_names[i]} HYDRA', color = colors[i], linestyle='--', marker='o')

plt.xlabel('Sequence Length (secondi)')
plt.ylabel('Secondi')
plt.yscale('log')
plt.title('Tempo di training')
plt.legend()
plt.grid(True)
plt.savefig('images/tempi_training_secondi.pdf')
plt.show()
